# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv("/content/anonymized_marks.csv")

# %%
print("First 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#     Student  Marks
# 0  Student1   14.5
# 1  Student2    1.0
# 2  Student3    5.0
# 3  Student4    5.0
# 4  Student5   13.0

# %%
print("\n--- Min & Max Marks ---")
print("Lowest Marks:", np.min(marks))
print("Highest Marks:", np.max(marks))
# Out:
# --- Min & Max Marks ---
# Lowest Marks: 0.0
# Highest Marks: 17.5

# %%
df = pd.read_csv("/content/anonymized_marks.csv")

#Assume column name is 'Marks'
marks = df['Marks']

# Basic Statistics
mean_val = np.mean(marks)
median_val = np.median(marks)
mode_val = stats.mode(marks, keepdims=True)

print("Mean:", mean_val)
print("Median:", median_val)
print("Mode:", mode_val.mode[0])

# Histogram (visual check)
plt.hist(marks, bins=10)
plt.title("Distribution of Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# Q-Q Plot (for normality check)
stats.probplot(marks, dist="norm", plot=plt)
plt.title("Q-Q Plot")
plt.show()

#Interpretation
alpha = 0.05
if p > alpha:
    print("Data is normally distributed ")
else:
    print("Data is NOT normally distributed ")
# Out:
# Mean: 7.88135593220339
# Median: 6.0
# Mode: 6.0
# Data is NOT normally distributed

# %%
print("Variance:", np.var(marks))
print("Standard Deviation:", np.std(marks))
print("Range:", np.max(marks) - np.min(marks))
# Out:
# Variance: 24.901177822464806
# Standard Deviation: 4.9901079970742925
# Range: 17.5

# %%
print("25th percentile:", np.percentile(marks, 25))
print("50th percentile (median):", np.percentile(marks, 50))
print("75th percentile:", np.percentile(marks, 75))
# Out:
# 25th percentile: 4.0
# 50th percentile (median): 6.0
# 75th percentile: 12.25

# %%
plt.boxplot(marks)
plt.title("Boxplot of Marks")
plt.show()

# %%
import seaborn as sns
sns.histplot(marks, kde=True)
plt.show()

# %%
Q1 = marks.quantile(0.25)
Q3 = marks.quantile(0.75)
IQR = Q3 - Q1

outliers = df[(marks < Q1 - 1.5*IQR) | (marks > Q3 + 1.5*IQR)]
print(outliers)
# Out:
# Empty DataFrame
# Columns: [Student, Marks, Grade]
# Index: []
